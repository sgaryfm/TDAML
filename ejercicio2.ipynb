# %% [markdown]
# Ejercicio 1

# %%
print("esto es una prueba")
# Out:
# esto es una prueba

# %%
var = "variable string"

print(var)
# Out:
# variable string

# %%
var[0:5]
# Out:
# 'varia'

# %%
lista = {var[0:8]}
print(lista)
# Out:
# {'variable'}
